# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127104_asia_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        41128771.0         20362329.0       20766442.0   20.700378
# 1        40099462.0         19844584.0       20254878.0   35.842000
# 2        38972230.0         19279929.0       19692301.0   36.051000
# 3        37769499.0         18679090.0       19090409.0   36.466000
# 4        36686784.0         18136922.0       18549862.0   36.927000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.343087                        9.0                   21.36864
# 1    7.344000                        9.0                   21.36864
# 2    7.113000                        9.0                   18.48131
# 3    6.791000                        9.0                   18.33941
# 4    6.981000                        9.0                   18.12015
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     28.950359                            31.756573
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1316, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.316000e+03       1.316000e+03     1.316000e+03  1316.000000
# mean       9.020217e+07       4.433594e+07     4.586623e+07    20.700378
# std        2.549317e+08       1.240024e+08     1.309465e+08     7.692176
# min        2.582080e+05       1.249510e+05     1.332570e+05     5.100000
# 25%        4.382818e+06       2.121473e+06     2.311564e+06    15.272250
# 50%        1.822701e+07       9.013542e+06     9.061772e+06    20.216500
# 75%        6.135766e+07       3.051728e+07     3.080141e+07    24.321000
# max        1.417173e+09       6.915285e+08     7.311805e+08    52.073000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1316.000000                1316.000000                1316.000000
# mean      6.343087                   8.913545                  21.368640
# std       2.669834                   1.797383                   7.752528
# ...

# %% [markdown]
# **TODO**: Give your obervation here
#
# - **Data Import:** The code successfully imports a cleaned dataset from the specified file path using the `pd.read_csv` function. The dataset appears to have columns representing various demographic, economic, and social indicators.
# - **Data Description:** The code creates a copy of the dataset `df_copy` after dropping the *Year* and *Country* columns. This is a common practice when analyzing numerical features because these two columns are not numerical and may not be relevant for certain types of analysis.
# - **Descriptive Statistics:** The code calculates and displays basic descriptive statistics for the numerical columns in the dataset using the `df_copy.describe()` method. These statistics include the count, mean, standard deviation, minimum, maximum, and quartiles for each numerical feature.
# - **Dataset Observations:**
#     - The dataset contains 1,316 rows and multiple numerical columns, each representing different variables for various countries over different years.
#     - The *Total Population* column, on average, has around 90 million, with a significant standard deviation, indicating a wide range of population sizes in the dataset.
#     - The *Birth Rate* and *Death Rate* columns have relatively low standard deviations, suggesting that these rates do not vary widely across countries and years.
#     - Other columns like *Employment in Agriculture(%)* and *Employment in Industry(%)* also have varying means and standard deviations, indicating differences in employment distribution across countries.
#     - There are indicators related to energy consumption, life expectancy, school enrollment, and more.
# Overall, the code and dataset are well-prepared for numerical analysis, and further exploration and insights can be derived from the descriptive statistics presented in the output.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# Assuming you have a dataset named 'data' in a DataFrame format
# Sort by 'Total Population' and select top 10 countries
top_10_countries = df_copy.sort_values(by='Total Population', ascending=False).head(10)

# Calculate the correlation matrix for these countries
correlation_matrix = top_10_countries.corr()

# Visualize the correlation using a heatmap
plt.figure(figsize=(15, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix for Top 10 Countries by Population')
plt.show()

# %% [markdown]
# **YOUR ANSWER**
# - **Total Population:**
#     - It has a strong positive correlation (0.79) with the Female Population, which makes sense since they are directly related. Similarly, it has a strong correlation with the Male Population. These are expected outcomes.
#     - The correlation with other features is relatively low.
# - **Birth Rate and Death Rate:**
#     - Birth Rate has a moderate negative correlation with Female Employment in Industry (-0.48) suggesting that as more females are employed in industries, the birth rate might decrease.
#     - Death Rate shows a slight negative correlation with GDP in USD (-0.4) suggesting economic prosperity might be associated with better healthcare and hence lower death rates.
# - **Economic Indicators (GDP, National Income, etc.):**
#     - GDP in USD shows a moderate positive correlation with Electric Power Consumption (0.65) indicating that countries with higher GDPs tend to have higher electric power consumption.
# - **Employment:**
#     - Female Employment in Agriculture has a moderate negative correlation with Female Employment in Industry (-0.6), indicating a shift of female workforce from agriculture to industry in these populous countries.
# - **Energy Consumption:**
#     - Electric Power Consumption has a moderate negative correlation with Renewable Energy Consumption (-0.58), implying countries with high electric power consumption may rely less on renewable energy sources.
#     - It also has a moderate positive correlation with Fossil Fuel Consumption (0.58), suggesting the major sources of electric power might be fossil fuels.
# - **Education:**
#     - There is a slight positive correlation between School Enrollment (both primary and tertiary) and GDP in USD (0.23 and 0.21 respectively). This suggests that as the economic condition of a country improves, the enrollment rates might also see an upward trend.
#
# **In summary, for the top 10 most populous countries:** There are shifts in employment sectors, especially for females moving from agriculture to industry. Economic prosperity seems to be associated with higher electric consumption, and a larger share of it might be coming from non-renewable sources. Education enrollment, especially in primary and tertiary levels, seems to improve with economic conditions.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
bottom_10_countries = df_copy.sort_values(by='Total Population', ascending=True).head(10)

# Calculate the correlation matrix for these countries
correlation_matrix_small = bottom_10_countries.corr()

# Visualize the correlation using a heatmap
plt.figure(figsize=(15, 15))
sns.heatmap(correlation_matrix_small, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix for Top 10 Countries with the Smallest Population')
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?
#
# - **Total Population vs. Male and Female Population:** The features *Total Population*, *Male Population*, and *Female Population* are extremely highly correlated, with correlations near or above 0.98. Since *Male Population** and *Female Population* can be effectively represented by *Total Population*, we might consider dropping one or both of them.
# - **Life Expectancy:** *Male Life Expectancy* and *Female Life Expectancy* have significant correlations with multiple variables, suggesting their potential importance. However, we may need to evaluate whether retaining both is necessary, given that they might carry similar information.
# - **GDP and National Income per Capita:** Both these features show significant correlations with various other features. While they're not perfectly correlated with each other, they might still convey similar information. We might choose to retain one over the other.
# - **Education Metrics:** *School enrollment, primary* and *Primary completion rate* are relatively weakly correlated with many other features, suggesting that they might not be as influential in the context of the smallest countries. We could consider their relevance to our specific study and potentially drop them if they are not essential.
# - **Renewable Energy Consumption vs. Fossil Fuel Consumption:** These two features might be conveying opposite trends in energy consumption, and both might be relevant to certain studies. However, if we're strictly looking to reduce feature count, we might assess which of the two aligns more with our study's goals.
# - **Agriculture Value Added:** This feature seems to have moderate correlations with many other variables. If our study isn't focused on agriculture, we could consider dropping it, but only after evaluating its significance based on our specific research question.
#
# In conclusion, while correlations provide insights into relationships between features, the decision to drop features should also factor in the context and goals of our analysis. Features with weaker correlations aren't necessarily unimportant; their relevance depends on the specific questions you're trying to answer. Always ensure that any feature removal is aligned with the objectives of our research.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate      Country
# 0        42.601621  Afghanistan
# 46       36.332442  Yemen, Rep.
# 14       33.036156         Iraq
# 31       32.258621     Pakistan
# 39       30.229478   Tajikistan

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate             Country
# 34       14.026539  Russian Federation
# 10       11.875182             Georgia
# 0         9.438110         Afghanistan
# 28        9.436503             Myanmar
# 1         9.181610             Armenia

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
#
# - **About Average Birth Rate:**
#     - It shows the average birth rate for five countries: `Afghanistan`, `Yemen (Republic of Yemen)`, `Iraq`, `Pakistan`, and `Tajikistan`.
#     - All the countries listed have relatively high average birth rates, though the exact rates are not numerically labeled on the y-axis.
#     - `Afghanistan` has the highest average birth rate among the countries shown, followed closely by `Yemen`, then `Iraq`, `Pakistan`, and `Tajikistan`, in descending order.
# - **About Average Death Rate:**
#     - This graph displays the average death rate for five different countries: `Russian Federation`, `Georgia`, `Afghanistan`, `Myanmar`, and `Armenia`.
#     - The graph can be observed that the `Russian Federation` has the highest average death rate among the countries listed, with `Georgia` following.
#     - `Afghanistan`, which also appeared in the first graph with the highest birth rate, shows a lower average death rate compared to the `Russian Federation` and `Georgia` in this graph.
#     - `Myanmar` and `Armenia` appear to have slightly lower average death rates than `Afghanistan`.
# -   **Observations Combining Both Graphs:**
#     - `Afghanistan` is the only country that appears on both graphs. When comparing the two, it seems to have a high birth rate and a moderately high death rate relative to the selection of countries displayed.
#     - The graphs compare different sets of countries, making it challenging to draw conclusions about trends without additional context or data.
#     - Neither graph has a legend or a clear indication of the time period these averages cover, nor do they provide a numerical scale, which would be essential for a detailed analysis.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# **A Possible Question:** Which top 5 countries have the highest average percentage of employment in agriculture, and how does this compare with their employment in industry?
#
# **Why This Question Is Relevant:** This question will give us insight into the economic structure of the top countries where agriculture is a major employment sector, compared to industrial employment. It can highlight dependencies on agriculture and potential vulnerabilities or strengths in a country's economy.
#
# **Answering this question will:** Help in understanding the economic focus of different countries and the potential need for economic diversification or support for the agricultural sector.
#
# **How we answer this question:** Find the top 5 countries with the highest average percentage of employment in agriculture and compare it with their employment in industry.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: Construct a dataframe that averages the relevant indicators for employment sectors for each country.

# %%
# YOUR CODE HERE
# Create a new dataframe for employment analysis
employment_sector_df = pd.DataFrame()

# Calculate the averages for each relevant feature by country
employment_sector_df["Avg.Employment in Agriculture(%)"] = cleaned_df.groupby("Country")["Employment in Agriculture(%)"].mean()
employment_sector_df["Avg.Employment in Industry(%)"] = cleaned_df.groupby("Country")["Employment in Industry(%)"].mean()

# Set the index as a column - countries
employment_sector_df["Country"] = employment_sector_df.index

# Drop the index
employment_sector_df.reset_index(drop=True, inplace=True)

# Sort the dataframe based on the average employment in agriculture, descending
employment_sector_df.sort_values("Avg.Employment in Agriculture(%)", inplace=True, ascending=False)

# Take the top 5 countries for visualization
top_employment_sector_df = employment_sector_df.head(5)

# Display
top_employment_sector_df
# Out:
#     Avg.Employment in Agriculture(%)  Avg.Employment in Industry(%)  \
# 23                         71.188259                       7.737921
# 29                         67.655964                      13.910593
# 5                          61.138863                       8.581997
# 7                          56.388340                      16.121110
# 0                          54.147977                      14.288790
#
#         Country
# 23      Lao PDR
# 29        Nepal
# 5        Bhutan
# 7      Cambodia
# 0   Afghanistan

# %% [markdown]
# Step 02: Visualize the data using a bar chart to compare these top countries.

# %%
# Choose a country for the demonstration, e.g., 'CountryName'
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(12, 6))

# Plot the average employment in agriculture
sns.barplot(x="Avg.Employment in Agriculture(%)", y="Country", data=top_employment_sector_df,
            label="Agriculture", color="g")

# Plot the average employment in industry on top of the agriculture
sns.barplot(x="Avg.Employment in Industry(%)", y="Country", data=top_employment_sector_df,
            label="Industry", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 100), ylabel="",
       xlabel="Average Employment in Agriculture vs Industry (%)")
sns.despine(left=True, bottom=True)

# Add a title to the plot
plt.title('Top 5 Countries with Highest Average Employment in Agriculture vs Industry', size=16)

# Show the plot
plt.show()

# %% [markdown]
# **MY OBSERVATION**

# %% [markdown]
# - **Agricultural Dominance:** In all five countries listed, the agriculture sector employs a larger percentage of the population than the industrial sector. This indicates a significant reliance on agriculture as the backbone of their economies.
# - **Highest in Agriculture:** `Lao PDR` appears to have the highest percentage of its employment in agriculture, surpassing 80% of the workforce, with a very small portion employed in industry.
# - **Significant Agricultural Employment:** Nepal and Bhutan also have a high percentage of their populations employed in agriculture, both showing slightly more than 60% agricultural employment.
# - **Comparatively Lower in Industry:** `Cambodia` and `Afghanistan` show a higher percentage of employment in the industry compared to the other three countries, but agriculture remains the dominant employment sector.
# - **Economic Structure Implications:** The chart indicates that these top 5 countries have an economy that is strongly dependent on agriculture, with industrial sectors being much smaller in comparison.
#
# In conclusion, the top 5 countries with the highest average percentage of employment in agriculture are `Lao PDR, Nepal, Bhutan, Cambodia, and Afghanistan`. In these countries, the employment percentage in agriculture is substantially higher than in industry, emphasizing a pronounced reliance on agriculture for livelihoods. This economic structure could suggest that these countries are potentially vulnerable to agricultural volatility due to factors such as climate change, market prices, and international trade policies. However, it could also indicate a strong capacity for sustainable agricultural practices and potential for growth in agritourism and organic markets. The lower relative percentage of industrial employment also suggests that these economies might be less industrialized and could either represent an untapped potential for industrial development or a strategic focus on sustainable agricultural development.

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# **A Possible Question:** What is the distribution of renewable energy consumption compared to fossil fuel consumption across these countries?
#
# **Why This Question Is Relevant:** Understanding the distribution of renewable versus fossil fuel energy consumption can offer insights into the sustainability practices of different countries and indicate how prepared they are for a transition to cleaner energy sources. This information is crucial in the context of global efforts to combat climate change and reduce greenhouse gas emissions.
#
# **Answering this question will:**
# - Highlight countries that are leading in renewable energy consumption, setting an example for sustainable energy use.
# - Indicate countries with high reliance on fossil fuels, possibly identifying areas where policy intervention could encourage more renewable energy usage.
# - Show global trends in energy consumption which are critical for assessing progress towards international climate goals.
#
# **How we answer this question:**
# - Extract data on renewable energy consumption percentages and fossil fuel consumption percentages for each country.
# - Create a composite bar chart where each country is represented by two bars side by side, one for renewable and one for fossil fuel consumption, to directly compare the two within each country.
# - Alternatively, create a bar chart for select countries to represent the proportion of renewable to fossil fuel consumption, which can quickly communicate the share of each energy type in a country's energy profile.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: Construct a dataframe that aggregates the average female and male employment percentages in agriculture and industry for each country.

# %%
# YOUR CODE HERE
# Create a new dataframe for average renewable and fossil fuel consumption
energy_consumption_df = pd.DataFrame()

# Calculate average renewable and fossil fuel consumption for each country
energy_consumption_df["Avg.Renewable Consumption (%)"] = cleaned_df.groupby("Country")["Renewable Energy Consumption (%)"].mean()
energy_consumption_df["Avg.Fossil Fuel Consumption (%)"] = cleaned_df.groupby("Country")["Fossil Fuel Consumption (%)"].mean()

# Set the index as a column - countries
energy_consumption_df["Country"] = energy_consumption_df.index

# Drop the index
energy_consumption_df.reset_index(drop=True, inplace=True)

# Sort the dataframe based on renewable energy consumption
energy_consumption_df.sort_values("Avg.Renewable Consumption (%)", inplace=True, ascending=False)

# Display the top 5 countries
energy_consumption_df.head()
# Out:
#     Avg.Renewable Consumption (%)  Avg.Fossil Fuel Consumption (%)   Country
# 5                       87.123851                        67.168073    Bhutan
# 29                      81.681631                        30.356281     Nepal
# 28                      73.373774                        41.523272   Myanmar
# 7                       67.466631                        40.049083  Cambodia
# 23                      66.316351                        78.362752   Lao PDR

# %% [markdown]
# Step 02: Visualize the data using bar charts.

# %%
# Now we melt the dataframe to have a suitable structure for sns.barplot
# Make sure to get the top 10 countries sorted by renewable consumption
top_countries = energy_consumption_df.head(5)
melted_df = top_countries.melt(id_vars="Country", value_vars=['Avg.Renewable Consumption (%)', 'Avg.Fossil Fuel Consumption (%)'], var_name="Type", value_name="Average Consumption (%)")

# Plotting the distribution for top countries
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
ax = sns.barplot(x='Country', y='Average Consumption (%)', hue='Type', data=melted_df)

plt.xticks(rotation=45)
plt.title("Top 5 Countries by Renewable and Fossil Fuel Energy Consumption")
plt.ylabel("Average Consumption (%)")
plt.xlabel("Country")
plt.legend(title='Energy Type')
plt.tight_layout() # This will adjust the plot to ensure everything fits without overlap
plt.show()

# %% [markdown]
# **MY OBSERVATION**

# %% [markdown]
# - **Renewable vs. Fossil Fuel Energy Consumption:** For each country shown, the consumption of renewable energy is higher than that of fossil fuels. This suggests a strong orientation towards renewable energy sources in these countries.
# - **High Renewable Energy Utilization:** `Bhutan` and `Nepal` stand out with the highest renewable energy consumption percentages compared to fossil fuels, indicating that these countries have leveraged their natural resources.
# - **Moderate Renewable Energy Utilization:** `Myanmar` and `Cambodia` show a good balance between renewable and fossil fuel consumption but still lean significantly towards renewable sources.
# - **Lower Gap in Lao PDR:** `Lao PDR` exhibits a lower gap between renewable and fossil fuel energy consumption. This might suggest that while renewable energy is predominant, there's still a considerable reliance on fossil fuels compared to the other countries displayed.
# - **Uniformity in Preference for Renewable Sources:** Across all these countries, there is a consistent pattern where renewable energy consumption is favored over fossil fuel consumption. This could reflect geographic, economic, and policy factors that encourage the use of renewable resources.
#
# In conclusion, the distribution of renewable energy consumption compared to fossil fuel consumption across these countries leans significantly towards renewable energy. It indicates that these countries are potentially well-positioned to transition to cleaner energy sources, which is crucial for reducing greenhouse gas emissions and combating climate change. This distribution can be seen as a positive sign of sustainable practices and may reflect policy decisions, availability of renewable resources, and investment in renewable energy infrastructure. Each country's specific context would influence their respective energy profiles, but overall, the focus on renewable is apparent.
